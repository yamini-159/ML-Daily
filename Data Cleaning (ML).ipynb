# %% [markdown]
# #Data cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #load the data

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe( include = "object")
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %% [markdown]
# #missing values

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
missing_percent = (df.isnull().sum()/(len(df)))

# %%
missing_percent
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.198653
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.002245
# class          0.000000
# who            0.000000
# adult_male     0.000000
# deck           0.772166
# embark_town    0.002245
# alive          0.000000
# alone          0.000000
# dtype: float64

# %%
df["age"].hist()
# Out:
# <Axes: >

# %%
df["age"] = df["age"].fillna(df["age"].median())

# %%
df["embarked"] = df["embarked"].fillna(df["embarked"].mode()[0])

# %%
df["embarked"].mode()[0]
# Out:
# 'S'

# %%
df["embark_town"] = df["embark_town"].fillna(df["embark_town"].mode()[0])

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         0
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
df.drop(columns = ["deck"],inplace = True)

# %%
df.isnull().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %% [markdown]
# #duplicate data

# %%
df.duplicated().sum()
# Out:
# np.int64(116)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #data type cleaning

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
#bool to int changing
df["adult_male"] = df["adult_male"].astype(int)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18924\1628577331.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["adult_male"] = df["adult_male"].astype(int)

# %%
df["alone"] = df["alone"].astype(int)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18924\1074949820.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["alone"] = df["alone"].astype(int)

# %%
df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male        int64
# embark_town      object
# alive            object
# alone             int64
# dtype: object

# %%
df["sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["sex"] = df["sex"].str.lower()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18924\985854172.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sex"] = df["sex"].str.lower()

# %%
df["embark_town"] = df["embark_town"].str.strip()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18924\4241902304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["embark_town"] = df["embark_town"].str.strip()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man           1  Southampton    no      0
# 1  woman           0    Cherbourg   yes      0
# 2  woman           0  Southampton   yes      1
# 3  woman           0  Southampton   yes      0
# 4    man           1  Southampton    no      1

# %% [markdown]
# #outliers

# %%
sns.boxplot(df["fare"])
# Out:
# <Axes: ylabel='fare'>

# %%
Q1 = df["fare"].quantile(0.25)
Q3 = df["fare"].quantile(0.75)
IQR = Q3-Q1
lower = Q1-1.5*IQR
upper = Q3+1.5*IQR

# %% [markdown]
# #Identify outliers

# %%
outliers = df[(df["fare"]<lower) | (df["fare"]>upper)]

# %%
outliers
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 54          0       1    male  65.0      0      1  61.9792        C   First
# 74          1       3    male  32.0      0      0  56.4958        S   Third
# 92          0       1    male  46.0      1      0  61.1750        S   First
# 97          1       1    male  23.0      0      1  63.3583        C   First
# 151         1       1  female  22.0      1      0  66.6000        S   First
# 155         0       1    male  51.0      0      1  61.3792        C   First
# 159         0       3    male  28.0      8      2  69.5500        S   Third
# 166         1       1  female  28.0      0      1  55.0000        S   First
# 169         0       3    male  28.0      0      0  56.4958        S   Third
# 180         0       3  female  28.0      8      2  69.5500        S   Third
# 309         1       1  female  30.0      0      0  56.9292        C   First
# 329         1       1  female  16.0      0      1  57.9792        C   First
# 336         0       1    male  29.0      1      0  66.6000        S   First
# 356         1       1  female  22.0      0      1  55.0000        S   First
# 369         1       1  female  24.0      0      0  69.3000        C   First
# 370         1       1    male  25.0      1      0  55.4417        C   First
# 434         0       1    male  50.0      1      0  55.9000        S   First
# 509         1       3    male  26.0      0      0  56.4958        S   Third
# 513         1       1  female  54.0      1      0  59.4000        C   First
# 523         1       1  female  44.0      0      1  57.9792        C   First
# 540         1       1  female  36.0      0      2  71.0000        S   First
# 577         1       1  female  39.0      1      0  55.9000        S   First
# 599         1       1    male  49.0      1      0  56.9292        C   First
# 615         1       2  female  24.0      1      2  65.0000        S  Second
# 643         1       3    male  28.0      0      0  56.4958        S   Third
# 690         1       1    male  31.0      1      0  57.0000        S   First
# 745         0       1    male  70.0      1      1  71.0000        S   First
# 754         1       2  female  48.0      1      2  65.0000        S  Second
# 781         1       1  female  17.0      1      0  57.0000        S   First
#
#        who  adult_male  embark_town alive  alone
# 1    woman           0    Cherbourg   yes      0
# 54     man           1    Cherbourg    no      0
# 74     man           1  Southampton   yes      1
# 92     man           1  Southampton    no      0
# 97     man           1    Cherbourg   yes      0
# 151  woman           0  Southampton   yes      0
# 155    man           1    Cherbourg    no      0
# 159    man           1  Southampton    no      0
# 166  woman           0  Southampton   yes      0
# 169    man           1  Southampton    no      1
# 180  woman           0  Southampton    no      0
# 309  woman           0    Cherbourg   yes      1
# 329  woman           0    Cherbourg   yes      0
# 336    man           1  Southampton    no      0
# 356  woman           0  Southampton   yes      0
# 369  woman           0    Cherbourg   yes      1
# 370    man           1    Cherbourg   yes      0
# 434    man           1  Southampton    no      0
# 509    man           1  Southampton   yes      1
# 513  woman           0    Cherbourg   yes      0
# 523  woman           0    Cherbourg   yes      0
# 540  woman           0  Southampton   yes      0
# 577  woman           0  Southampton   yes      0
# 599    man           1    Cherbourg   yes      0
# 615  woman           0  Southampton   yes      0
# 643    man           1  Southampton   yes      1
# 690    man           1  Southampton   yes      0
# 745    man           1  Southampton    no      0
# 754  woman           0  Southampton   yes      0
# 781  woman           0  Southampton   yes      0

# %% [markdown]
# ## remove outliers

# %%
df = df[(df["fare"]>=lower) & (df["fare"]<=upper)]

# %%
sns.boxplot(df["fare"])
# Out:
# <Axes: ylabel='fare'>

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male  28.0      0      0   8.4583        Q  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man           1  Southampton    no      0
# 2  woman           0  Southampton   yes      1
# 3  woman           0  Southampton   yes      0
# 4    man           1  Southampton    no      1
# 5    man           1   Queenstown    no      1

# %%
df["survived"].value_counts()
# Out:
# survived
# 0    418
# 1    225
# Name: count, dtype: int64

# %%
df["pclass"].value_counts()
# Out:
# pclass
# 3    395
# 2    157
# 1     91
# Name: count, dtype: int64

# %% [markdown]
# #final validation

# %%
df.isnull().sum()
df.dtypes
df.shape
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare  \
# count  643.000000  643.000000  643.000000  643.000000  643.000000  643.000000
# mean     0.349922    2.472784   28.666407    0.486781    0.387247   17.545334
# std      0.477316    0.730162   13.542451    0.952646    0.839611   11.941606
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   21.000000    0.000000    0.000000    7.895800
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   13.000000
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   26.000000
# max      1.000000    3.000000   80.000000    5.000000    6.000000   53.100000
#
#        adult_male       alone
# count  643.000000  643.000000
# mean     0.608087    0.620529
# std      0.488557    0.485633
# min      0.000000    0.000000
# 25%      0.000000    0.000000
# 50%      1.000000    1.000000
# 75%      1.000000    1.000000
# max      1.000000    1.000000

# %% [markdown]
# #save data to new files

# %%
df.to_csv("titanic_data_cleaned",index = False)

# %% [markdown]
# #reusable data quality report function

# %%
def data_quality_report(df):
    report = {
        "shape" : df.shape,
        "missing_values" : df.isnull().sum(),
        "duplicate_count": int(df.duplicated().sum()),
        "data_types": df.dtypes.astype(str).to_dict()
}
